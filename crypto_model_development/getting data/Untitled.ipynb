# %%
import requests

# %%
resp = requests.get('https://api.binance.us/api/v3/klines?symbol=LTCBTC&interval=1h&limit=10')

data = resp.json()
for i in data:
    print(i)
# Out:
# [1647190800000, '0.00270300', '0.00270400', '0.00269800', '0.00270400', '20.46000000', 1647194399999, '0.05531655', 6, '20.42000000', '0.05520863', '0']
# [1647194400000, '0.00270500', '0.00271200', '0.00270500', '0.00270800', '7.41000000', 1647197999999, '0.02008333', 7, '7.30000000', '0.01978545', '0']
# [1647198000000, '0.00270800', '0.00271100', '0.00270600', '0.00271100', '13.64000000', 1647201599999, '0.03693680', 8, '5.06000000', '0.01371766', '0']
# [1647201600000, '0.00270400', '0.00270400', '0.00268800', '0.00269300', '1230.76000000', 1647205199999, '3.32523711', 154, '3.75000000', '0.01011607', '0']
# [1647205200000, '0.00269800', '0.00270100', '0.00269300', '0.00269300', '3.70000000', 1647208799999, '0.00998881', 5, '3.33000000', '0.00899220', '0']
# [1647208800000, '0.00270300', '0.00271600', '0.00268800', '0.00270500', '69.45000000', 1647212399999, '0.18786123', 53, '38.33000000', '0.10381218', '0']
# ...
